# %% [markdown]
# # Olist Visualisation
#
# **Цель этапа** — отразить метрики на дашборде с использованием Tableau.

# %% [markdown]
# Ссылка на дашборд: https://public.tableau.com/views/ImpactofDeliveryDelaysonCustomerExperienceandOrderValue/Dashboard1?:language=en-US&publish=yes&:sid=&:redirect=auth&:display_count=n&:origin=viz_share_link
